# %% [markdown]
# # Política sobre IA
#
# ### 🤖 Uso de IA en Este Curso
#
# Te animamos a **usar herramientas de IA de manera reflexiva y responsable**, especialmente durante la **primera parte del semestre**, cuando estás construyendo habilidades fundamentales.
#
# #### ✅ Cómo Recomendamos Usar la IA
#
# Nuestro consejo es tratar la IA como un **asistente de aprendizaje**, no como un reemplazo de tu propio pensamiento:
#
# - Primero, **intenta el problema tú mismo**.
# - Usa herramientas de IA para:
#   - Ayudarte a **entender un concepto** en el que estés atascado
#   - Explicar **por qué algo no está funcionando**
#   - Apoyarte en la **depuración** de tu programa
# - Si usas explicaciones o ejemplos generados por IA, asegúrate de que realmente los **entiendes**.
#
# ⚠️ **No pidas a las herramientas de IA que generen directamente soluciones completas o código para ti.**
# Si alguna vez miras código generado por IA, deberías ser capaz de:
#
# - Explicar qué hace
# - Modificarlo
# - Reescribir una solución similar por tu cuenta en el futuro
#
# Si no puedes hacer eso, entonces el uso de IA no está ayudando a tu aprendizaje.
#
# ---
#
# #### 📌 Responsabilidad y Exámenes
#
# - **No aplicaremos activamente una política estricta de IA** durante las tareas.
# - Sin embargo, **los exámenes se toman de forma presencial**.
# - Durante los exámenes:
#   - Puedes usar una **hoja de referencia**
#   - Puedes consultar **tareas anteriores**
#   - **Las herramientas de IA no estarán disponibles**
#
# Esto significa que **eres completamente responsable de lo que sabes y puedes hacer en los exámenes**.
# Si dependes excesivamente de la IA durante el semestre, será muy difícil lograr una calificación sólida en el examen—y por lo tanto una calificación sólida en el curso en general.
#
# ---
#
# #### 🤝 No Estás Solo
#
# Recuerda que tienes acceso a un **gran equipo de instrucción** que está aquí para ayudarte a aprender:
#
# - Múltiples **horarios de consulta cada semana**
#   (**revisa el horario de consulta en el botón de inicio de canvas**)
#
# - **Soporte activo en Microsoft Teams**, donde respondemos preguntas lo más rápido posible
#
# Te animamos encarecidamente a usar **apoyo humano + uso reflexivo de IA** para construir una comprensión real y confianza.

# %%
# import json
# from jupyterquiz import display_quiz
# with open("jquiz1.json", "r") as file:
#     questions=json.load(file)

# display_quiz(questions,  border_radius=0)
